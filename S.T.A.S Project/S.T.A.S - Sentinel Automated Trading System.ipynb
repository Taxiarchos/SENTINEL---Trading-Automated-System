# %% [markdown]
# ### This is the S.T.A.S : Sentinel Trading Automated System
# ### This one is just the skeleton of a program that will be far more advanced
# ### and far more user friendly

# %%
# !pip install yfinance           #installazione di librerie nel virtualenv del jupyter notebook
# !pip install nbformat>=4.2.0
import nbformat
# Out:
# ERROR: Invalid requirement: '#installazione'

# %% [markdown]
# # BALANCE SHEET WITH YFINANCE

# %%
#Dati di prezzo, bilancio e dati di azione inserendo il ticker code

import yfinance as yf   
import pandas as pd

stock_name = input("Enter the ticker symbol (the code) of the stock you want to analyze: ")
msft = yf.Ticker(stock_name)
print("Now, a description of the stock and the company...\n")

info=[["Info", msft.info],["historical market data", msft.history(period="max")],["Actions", msft.actions],["Dividends", msft.dividends],["Splits", msft.splits],["Financials", msft.financials],
      ["Quarterly financials", msft.quarterly_financials],["Major holders", msft.major_holders],["Institutional holders", msft.institutional_holders],["Balance sheet", msft.balance_sheet],
      ["Quarterly Balance sheet", msft.quarterly_balance_sheet], ["Cash Flow", msft.cashflow], ["Quarterly cash flow", msft.quarterly_cashflow], ["Earnings", msft.earnings],
      ["Quarterly earnings", msft.quarterly_earnings], ["Sustainability", msft.sustainability],  ["Recommendations", msft.recommendations], ["Calendar of next events", msft.calendar],
      ["Options expirations", msft.options]]

for i in range(0,19):            #questo ciclo for scrive il nome del dataset e il dataset
    print(info[i][0])            #tipo "info" seguito dal dataset msft.info, "historical market data" seguito da msft.history(period="max")
    dataset=pd.DataFrame(info[i][1])
    print(dataset)
    print("\n")
# Out:
# Now, a description of the stock and the company...
#
# Info
# Empty DataFrame
# Columns: [zip, sector, fullTimeEmployees, longBusinessSummary, city, phone, state, country, companyOfficers, website, maxAge, address1, industry, ebitdaMargins, profitMargins, grossMargins, operatingCashflow, revenueGrowth, operatingMargins, ebitda, targetLowPrice, recommendationKey, grossProfits, freeCashflow, targetMedianPrice, currentPrice, earningsGrowth, currentRatio, returnOnAssets, numberOfAnalystOpinions, targetMeanPrice, debtToEquity, returnOnEquity, targetHighPrice, totalCash, totalDebt, totalRevenue, totalCashPerShare, financialCurrency, revenuePerShare, quickRatio, recommendationMean, exchange, shortName, longName, exchangeTimezoneName, exchangeTimezoneShortName, isEsgPopulated, gmtOffSetMilliseconds, quoteType, symbol, messageBoardId, market, annualHoldingsTurnover, enterpriseToRevenue, beta3Year, enterpriseToEbitda, 52WeekChange, morningStarRiskRating, forwardEps, revenueQuarterlyGrowth, sharesOutstanding, fundInceptionDate, annualReportExpenseRatio, totalAssets, bookValue, sharesShort, sharesPercentSharesOut, fundFamily, lastFiscalYearEnd, heldPercentInstitutions, netIncomeToCommon, trailingEps, lastDividendValue, SandP52WeekChange, priceToBook, heldPercentInsiders, nextFiscalYearEnd, yield, mostRecentQuarter, shortRatio, sharesShortPreviousMonthDate, floatShares, beta, enterpriseValue, priceHint, threeYearAverageReturn, lastSplitDate, lastSplitFactor, legalType, lastDividendDate, morningStarOverallRating, earningsQuarterlyGrowth, priceToSalesTrailing12Months, dateShortInterest, pegRatio, ytdReturn, forwardPE, lastCapGain, shortPercentOfFloat, ...]
# Index: []
#
# [0 rows x 152 columns]
#
#
# historical market data
#                    Open         High          Low        Close    Volume  \
# Date
# 2010-06-29     3.800000     5.000000     3.508000     4.778000  93831500
# 2010-06-30     5.158000     6.084000     4.660000     4.766000  85935500
# 2010-07-01     5.000000     5.184000     4.054000     4.392000  41094000
# 2010-07-02     4.600000     4.620000     3.742000     3.840000  25699000
# 2010-07-06     4.000000     4.000000     3.166000     3.222000  34334500
# ...                 ...          ...          ...          ...       ...
# 2021-10-25   950.530029  1045.020020   944.200012  1024.859985  62852100
# 2021-10-26  1024.689941  1094.939941  1001.440002  1018.429993  62415000
# 2021-10-27  1039.660034  1070.880005  1030.780029  1037.859985  38526500
# 2021-10-28  1068.310059  1081.000000  1054.199951  1077.040039  27213200
# 2021-10-29  1081.859985  1115.209961  1073.209961  1114.000000  29733600
#
#             Dividends  Stock Splits
# Date
# 2010-06-29          0           0.0
# 2010-06-30          0           0.0
# 2010-07-01          0           0.0
# 2010-07-02          0           0.0
# 2010-07-06          0           0.0
# ...               ...           ...
# 2021-10-25          0           0.0
# 2021-10-26          0           0.0
# 2021-10-27          0           0.0
# 2021-10-28          0           0.0
# 2021-10-29          0           0.0
#
# [2856 rows x 7 columns]
#
#
# Actions
#             Dividends  Stock Splits
# Date
# 2020-08-31        0.0           5.0
#
#
# Dividends
# Empty DataFrame
# Columns: [Dividends]
# Index: []
#
#
# Splits
#             Stock Splits
# Date
# 2020-08-31           5.0
#
#
# Financials
#                                            2020-12-31     2019-12-31  \
# Research Development                     1491000000.0   1343000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        1154000000.0   -665000000.0
# Minority Interest                        1454000000.0   1492000000.0
# Net Income                                721000000.0   -862000000.0
# Selling General Administrative           3188000000.0   2646000000.0
# Gross Profit                             6630000000.0   4069000000.0
# Ebit                                     1951000000.0     80000000.0
# Operating Income                         1951000000.0     80000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -784000000.0   -725000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                        292000000.0    110000000.0
# Total Revenue                           31536000000.0  24578000000.0
# Total Operating Expenses                29585000000.0  24498000000.0
# Cost Of Revenue                         24906000000.0  20509000000.0
# Total Other Income Expense Net           -797000000.0   -745000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops            862000000.0   -775000000.0
# Net Income Applicable To Common Shares    690000000.0   -870000000.0
#
#                                            2018-12-31     2017-12-31
# Research Development                     1460000000.0   1378000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       -1005000000.0  -2209000000.0
# Minority Interest                        1390000000.0   1395080000.0
# Net Income                               -976000000.0  -1962000000.0
# Selling General Administrative           2835000000.0   2477000000.0
# Gross Profit                             4042000000.0   2223000000.0
# Ebit                                     -253000000.0  -1632000000.0
# Operating Income                         -253000000.0  -1632000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -653000000.0   -477000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                         58000000.0     32000000.0
# Total Revenue                           21461000000.0  11759000000.0
# Total Operating Expenses                21714000000.0  13391000000.0
# Cost Of Revenue                         17419000000.0   9536000000.0
# Total Other Income Expense Net           -752000000.0   -577000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops          -1063000000.0  -2241000000.0
# Net Income Applicable To Common Shares   -976000000.0  -1962000000.0
#
#
# Quarterly financials
#                                            2021-09-30     2021-06-30  \
# Research Development                      611000000.0    576000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        1882000000.0   1293000000.0
# Minority Interest                        1441000000.0   1446000000.0
# Net Income                               1618000000.0   1142000000.0
# Selling General Administrative            994000000.0    973000000.0
# Gross Profit                             3660000000.0   2884000000.0
# Ebit                                     2055000000.0   1312000000.0
# Operating Income                         2055000000.0   1312000000.0
# Other Operating Expenses                          NaN     23000000.0
# Interest Expense                         -125000000.0    -84000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                        223000000.0    115000000.0
# Total Revenue                           13757000000.0  11958000000.0
# Total Operating Expenses                11702000000.0  10646000000.0
# Cost Of Revenue                         10097000000.0   9074000000.0
# Total Other Income Expense Net           -173000000.0    -19000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops           1659000000.0   1178000000.0
# Net Income Applicable To Common Shares   1618000000.0   1142000000.0
#
#                                            2021-03-31     2020-12-31
# Research Development                      666000000.0    522000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                         533000000.0    379000000.0
# Minority Interest                        1448000000.0   1454000000.0
# Net Income                                438000000.0    270000000.0
# Selling General Administrative           1056000000.0    969000000.0
# Gross Profit                             2215000000.0   2066000000.0
# Ebit                                      594000000.0    575000000.0
# Operating Income                          594000000.0    575000000.0
# Other Operating Expenses                 -101000000.0   -101000000.0
# Interest Expense                          -79000000.0   -241000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                         69000000.0     83000000.0
# Total Revenue                           10389000000.0  10744000000.0
# Total Operating Expenses                 9795000000.0  10169000000.0
# Cost Of Revenue                          8174000000.0   8678000000.0
# Total Other Income Expense Net            -61000000.0   -196000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops            464000000.0    296000000.0
# Net Income Applicable To Common Shares    438000000.0    270000000.0
#
#
# Major holders
#         0                                      1
# 0  18.98%        % of Shares Held by All Insider
# 1  41.20%       % of Shares Held by Institutions
# 2  50.85%        % of Float Held by Institutions
# 3    2756  Number of Institutions Holding Shares
#
#
# Institutional holders
#                               Holder    Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  58931414    2021-06-29  0.0587
# 1                     Blackrock Inc.  50452309    2021-06-29  0.0502
# 2            Capital World Investors  37282565    2021-06-29  0.0371
# 3           State Street Corporation  29828814    2021-06-29  0.0297
# 4        Baillie Gifford and Company  13853124    2021-09-29  0.0138
# 5      Geode Capital Management, LLC  12311100    2021-06-29  0.0123
# 6            Jennison Associates LLC  10332413    2021-06-29  0.0103
# 7                           FMR, LLC   9575696    2021-06-29  0.0095
# 8         Northern Trust Corporation   8166550    2021-06-29  0.0081
# 9  Norges Bank Investment Management   7790070    2020-12-30  0.0078
#
#          Value
# 0  40055682095
# 1  34292434427
# 2  25340959430
# 3  20274644875
# 4  10742820599
# 5   8367854670
# 6   7022941116
# 7   6508600571
# 8   5550804035
# 9   5497218696
#
#
# Balance sheet
#                              2020-12-31    2019-12-31    2018-12-31  \
# Intangible Assets          3.130000e+08  3.390000e+08  2.820000e+08
# Capital Surplus            2.726000e+10  1.273600e+10  1.024900e+10
# Total Liab                 2.846900e+10  2.619900e+10  2.342700e+10
# Total Stockholder Equity   2.222500e+10  6.618000e+09  4.923000e+09
# Minority Interest          1.454000e+09  1.492000e+09  1.390000e+09
# Other Current Liab         4.147000e+09  3.693000e+09  2.955000e+09
# Total Assets               5.214800e+10  3.430900e+10  2.974000e+10
# Common Stock               1.000000e+06  1.000000e+06           NaN
# Other Current Assets       2.380000e+08  2.460000e+08  1.930000e+08
# Retained Earnings         -5.399000e+09 -6.083000e+09 -5.318000e+09
# Other Liab                 3.302000e+09  2.969000e+09  2.318000e+09
# Good Will                  2.070000e+08  1.980000e+08  6.800000e+07
# Treasury Stock             3.630000e+08 -3.600000e+07 -8.000000e+06
# Other Assets               1.536000e+09  1.469000e+09  1.380000e+09
# Cash                       1.938400e+10  6.268000e+09  3.686000e+09
# Total Current Liabilities  1.424800e+10  1.066700e+10  9.993000e+09
# Short Long Term Debt       1.758000e+09  1.399000e+09  2.284000e+09
# Other Stockholder Equity   3.630000e+08 -3.600000e+07 -8.000000e+06
# Property Plant Equipment   2.337500e+10  2.019900e+10  1.969100e+10
# Total Current Assets       2.671700e+10  1.210300e+10  8.307000e+09
# Net Tangible Assets        2.170500e+10  6.081000e+09  4.573000e+09
# Net Receivables            1.903000e+09  1.324000e+09  9.490000e+08
# Long Term Debt             8.571000e+09  1.037500e+10  8.461000e+09
# Inventory                  4.101000e+09  3.552000e+09  3.113000e+09
# Accounts Payable           6.051000e+09  3.771000e+09  3.405000e+09
# Long Term Investments               NaN  1.000000e+06  1.200000e+07
#
#                              2017-12-31
# Intangible Assets          3.615020e+08
# Capital Surplus            9.178024e+09
# Total Liab                 2.302305e+10
# Total Stockholder Equity   4.237242e+09
# Minority Interest          1.395080e+09
# Other Current Liab         3.098379e+09
# Total Assets               2.865537e+10
# Common Stock               1.690000e+05
# Other Current Assets       1.553230e+08
# Retained Earnings         -4.974299e+09
# Other Liab                 4.196294e+09
# Good Will                  6.023700e+07
# Treasury Stock             3.334800e+07
# Other Assets               1.166193e+09
# Cash                       3.367914e+09
# Total Current Liabilities  7.674740e+09
# Short Long Term Debt       9.639320e+08
# Other Stockholder Equity   3.334800e+07
# Property Plant Equipment   2.049162e+10
# Total Current Assets       6.570520e+09
# Net Tangible Assets        3.815503e+09
# Net Receivables            5.153810e+08
# Long Term Debt             9.486248e+09
# Inventory                  2.263537e+09
# Accounts Payable           2.390250e+09
# Long Term Investments      5.304000e+06
#
#
# Quarterly Balance sheet
#                              2021-09-30    2021-06-30    2021-03-31  \
# Intangible Assets          2.690000e+08  2.830000e+08  2.990000e+08
# Capital Surplus            2.892200e+10  2.820500e+10  2.762300e+10
# Total Liab                 2.934000e+10  2.889600e+10  2.850700e+10
# Total Stockholder Equity   2.705300e+10  2.480400e+10  2.301700e+10
# Minority Interest          1.441000e+09  1.446000e+09  1.448000e+09
# Other Current Liab         5.024000e+09  4.621000e+09  4.412000e+09
# Total Assets               5.783400e+10  5.514600e+10  5.297200e+10
# Common Stock               1.000000e+06  1.000000e+06  1.000000e+06
# Other Current Assets       3.270000e+08  3.260000e+08  3.050000e+08
# Retained Earnings         -1.990000e+09 -3.608000e+09 -4.750000e+09
# Other Liab                 3.190000e+09  3.210000e+09  3.247000e+09
# Good Will                  2.010000e+08  2.030000e+08  2.060000e+08
# Treasury Stock             1.200000e+08  2.060000e+08  1.430000e+08
# Other Assets               3.114000e+09  2.937000e+09  2.918000e+09
# Cash                       1.606500e+10  1.622900e+10  1.714100e+10
# Total Current Liabilities  1.805100e+10  1.637100e+10  1.487700e+10
# Short Long Term Debt       1.207000e+09  1.082000e+09  1.415000e+09
# Other Stockholder Equity   1.200000e+08  2.060000e+08  1.430000e+08
# Property Plant Equipment   2.924800e+10  2.703000e+10  2.484400e+10
# Total Current Assets       2.500200e+10  2.469300e+10  2.470500e+10
# Net Tangible Assets        2.658300e+10  2.431800e+10  2.251200e+10
# Short Term Investments     3.000000e+07           NaN           NaN
# Net Receivables            2.000000e+09  2.159000e+09  1.913000e+09
# Long Term Debt             5.471000e+09  6.915000e+09  8.019000e+09
# Inventory                  5.199000e+09  4.733000e+09  4.132000e+09
# Accounts Payable           8.260000e+09  7.558000e+09  6.648000e+09
#
#                              2020-12-31
# Intangible Assets          3.130000e+08
# Capital Surplus            2.726000e+10
# Total Liab                 2.846900e+10
# Total Stockholder Equity   2.222500e+10
# Minority Interest          1.454000e+09
# Other Current Liab         4.147000e+09
# Total Assets               5.214800e+10
# Common Stock               1.000000e+06
# Other Current Assets       2.380000e+08
# Retained Earnings         -5.399000e+09
# Other Liab                 3.302000e+09
# Good Will                  2.070000e+08
# Treasury Stock             3.630000e+08
# Other Assets               1.536000e+09
# Cash                       1.938400e+10
# Total Current Liabilities  1.424800e+10
# Short Long Term Debt       1.758000e+09
# Other Stockholder Equity   3.630000e+08
# Property Plant Equipment   2.337500e+10
# Total Current Assets       2.671700e+10
# Net Tangible Assets        2.170500e+10
# Short Term Investments              NaN
# Net Receivables            1.903000e+09
# Long Term Debt             8.571000e+09
# Inventory                  4.101000e+09
# Accounts Payable           6.051000e+09
#
#
# Cash Flow
#                                              2020-12-31    2019-12-31  \
# Change To Liabilities                      2.423000e+09  1.447000e+09
# Total Cashflows From Investing Activities -3.132000e+09 -1.436000e+09
# Net Borrowings                            -2.488000e+09  7.980000e+08
# Total Cash From Financing Activities       9.973000e+09  1.529000e+09
# Change To Operating Activities            -1.165000e+09 -1.000000e+09
# Issuance Of Stock                          1.268600e+10  1.111000e+09
# Net Income                                 7.210000e+08 -8.620000e+08
# Change In Cash                             1.311800e+10  2.506000e+09
# Effect Of Exchange Rate                    3.340000e+08  8.000000e+06
# Total Cash From Operating Activities       5.943000e+09  2.405000e+09
# Depreciation                               2.322000e+09  2.092000e+09
# Other Cashflows From Investing Activities  1.230000e+08  4.600000e+07
# Change To Inventory                       -4.220000e+08 -4.290000e+08
# Change To Account Receivables             -6.520000e+08 -3.670000e+08
# Other Cashflows From Financing Activities -2.250000e+08 -3.800000e+08
# Change To Netincome                        2.536000e+09  1.336000e+09
# Capital Expenditures                      -3.232000e+09 -1.432000e+09
#
#                                              2018-12-31    2017-12-31
# Change To Liabilities                      2.203000e+09  8.570000e+08
# Total Cashflows From Investing Activities -2.337000e+09 -4.196000e+09
# Net Borrowings                             8.900000e+07  3.385000e+09
# Total Cash From Financing Activities       5.740000e+08  4.415000e+09
# Change To Operating Activities            -6.250000e+08 -1.150000e+09
# Issuance Of Stock                          2.960000e+08  6.590000e+08
# Net Income                                -9.760000e+08 -1.962000e+09
# Change In Cash                             3.120000e+08  1.980000e+08
# Effect Of Exchange Rate                   -2.300000e+07  4.000000e+07
# Total Cash From Operating Activities       2.098000e+09 -6.100000e+07
# Depreciation                               1.888000e+09  1.636000e+09
# Other Cashflows From Investing Activities  4.600000e+07  4.600000e+07
# Change To Inventory                       -1.023000e+09 -1.790000e+08
# Change To Account Receivables             -4.970000e+08 -2.500000e+07
# Other Cashflows From Financing Activities  1.890000e+08  3.710000e+08
# Change To Netincome                        9.690000e+08  6.710000e+08
# Capital Expenditures                      -2.319000e+09 -4.081000e+09
#
#
# Quarterly cash flow
#                                              2021-09-30    2021-06-30  \
# Investments                               -3.000000e+07 -3.000000e+07
# Change To Liabilities                      1.345000e+09  1.037000e+09
# Total Cashflows From Investing Activities -1.855000e+09 -1.515000e+09
# Net Borrowings                            -1.526000e+09 -1.588000e+09
# Total Cash From Financing Activities      -1.381000e+09 -1.549000e+09
# Change To Operating Activities            -9.930000e+08 -5.210000e+08
# Issuance Of Stock                          1.920000e+08  7.000000e+07
# Net Income                                 1.618000e+09  1.142000e+09
# Change In Cash                            -1.310000e+08 -8.980000e+08
# Effect Of Exchange Rate                   -4.200000e+07  4.200000e+07
# Total Cash From Operating Activities       3.147000e+09  2.124000e+09
# Depreciation                               7.610000e+08  6.810000e+08
# Change To Inventory                       -4.880000e+08 -5.810000e+08
# Change To Account Receivables              1.350000e+08 -2.590000e+08
# Other Cashflows From Financing Activities -4.700000e+07 -3.100000e+07
# Change To Netincome                        7.690000e+08  6.250000e+08
# Capital Expenditures                      -1.825000e+09 -1.515000e+09
# Other Cashflows From Investing Activities           NaN           NaN
#
#                                              2021-03-31    2020-12-31
# Investments                               -3.000000e+07 -3.000000e+07
# Change To Liabilities                      8.340000e+08  1.540000e+09
# Total Cashflows From Investing Activities -2.582000e+09 -1.047000e+09
# Net Borrowings                            -1.162000e+09 -2.305000e+09
# Total Cash From Financing Activities      -1.016000e+09  2.692000e+09
# Change To Operating Activities            -7.160000e+08 -3.760000e+08
# Issuance Of Stock                          1.830000e+08  5.043000e+09
# Net Income                                 4.380000e+08  2.700000e+08
# Change In Cash                            -2.178000e+09  4.898000e+09
# Effect Of Exchange Rate                   -2.210000e+08  2.340000e+08
# Total Cash From Operating Activities       1.641000e+09  3.019000e+09
# Depreciation                               6.210000e+08  6.180000e+08
# Change To Inventory                       -1.060000e+08  1.800000e+08
# Change To Account Receivables             -2.400000e+07 -1.020000e+08
# Other Cashflows From Financing Activities -3.700000e+07 -4.600000e+07
# Change To Netincome                        5.940000e+08  8.530000e+08
# Capital Expenditures                      -2.860000e+09 -1.164000e+09
# Other Cashflows From Investing Activities  6.000000e+06  1.220000e+08
#
#
# Earnings
#           Revenue    Earnings
# Year
# 2017  11759000000 -1962000000
# 2018  21461000000  -976000000
# 2019  24578000000  -862000000
# 2020  31536000000   721000000
#
#
# Quarterly earnings
#              Revenue    Earnings
# Quarter
# 4Q2020   10744000000   270000000
# 1Q2021   10389000000   438000000
# 2Q2021   11958000000  1142000000
# 3Q2021   13757000000  1618000000
#
#
# Sustainability
#                              Value
# 2021-9
# palmOil                      False
# controversialWeapons         False
# gambling                     False
# socialScore                  17.31
# nuclear                      False
# furLeather                   False
# alcoholic                    False
# gmo                          False
# catholic                     False
# socialPercentile              None
# peerCount                       37
# governanceScore               10.2
# environmentPercentile         None
# animalTesting                False
# tobacco                      False
# totalEsg                     30.46
# highestControversy               3
# esgPerformance            OUT_PERF
# coal                         False
# pesticides                   False
# adult                        False
# percentile                   61.16
# peerGroup              Automobiles
# smallArms                    False
# environmentScore              2.95
# governancePercentile          None
# militaryContract             False
#
#
# Recommendations
#                                   Firm    To Grade From Grade Action
# Date
# 2012-02-16 07:42:00          JP Morgan  Overweight              main
# 2012-02-16 13:53:00         Wunderlich        Hold              down
# 2012-02-17 06:17:00         Oxen Group         Buy              init
# 2012-03-26 07:31:00         Wunderlich         Buy                up
# 2012-05-22 05:57:00        Maxim Group         Buy              init
# ...                                ...         ...        ...    ...
# 2021-10-21 12:42:25             Mizuho         Buy              main
# 2021-10-21 14:23:55       Roth Capital     Neutral              main
# 2021-10-21 14:33:04  Canaccord Genuity         Buy              main
# 2021-10-27 12:15:11      Goldman Sachs         Buy              main
# 2021-10-28 14:15:36      Piper Sandler  Overweight              main
#
# [415 rows x 4 columns]
#
#
# Calendar of next events
#                                     0                    1
# Earnings Date     2022-01-25 21:00:00  2022-01-31 21:00:00
# Earnings Average                 1.91                 1.91
# Earnings Low                     1.39                 1.39
# Earnings High                    2.54                 2.54
# Revenue Average           15091900000          15091900000
# Revenue Low               13506000000          13506000000
# Revenue High              16577700000          16577700000
#
#
# Options expirations
#              0
# 0   2021-11-05
# 1   2021-11-12
# 2   2021-11-19
# 3   2021-11-26
# 4   2021-12-03
# 5   2021-12-17
# 6   2022-01-21
# 7   2022-02-18
# 8   2022-03-18
# 9   2022-05-20
# 10  2022-06-17
# 11  2022-09-16
# 12  2023-01-20
# 13  2023-03-17
# 14  2023-06-16
# 15  2024-01-19

# %% [markdown]
# # STOCK PRICE PLOT

# %%
import plotly.express as px

stock_price=pd.DataFrame(info[1][1])
stock_price.reset_index(inplace=True)

closing_price=stock_price["Close"]   #stock_price[close] viene salvato in closing_price perchè servirà spesso più avanti!!
Date=stock_price["Date"]

stockplot = px.line(x=Date, y=closing_price, labels=dict(x="Date", y="Price"))
stockplot.show()

# %% [markdown]
# # MOBILE AVERAGES PLOT

# %%
def MobileAverage(MArange, Date):   #Creazione della media mobile , cerca la formula su wikipedia della media mobile per capirla
        while (MArange >= len(Date)):
            print("the range is too wide, we advice using no more than 250 days...")
            MArange
    
        MA=[]
        for i in range(0,len(Date)):
            if((len(Date)-(i+MArange)) <= 0):
                    value=closing_price[i:len(Date)].mean()
                    MA.append(value)
            else:
                    value=closing_price[i:i+MArange].mean()
                    MA.append(value)
            
        return MA
    
def MA_signal_Fermat():                  #segnale per capire se la media mobile si flette cambiando da crescente a
    Presignal_List = []                  #decrescente o viceversa usando il teorema di Fermat
    MA10 = MobileAverage(10, Date)
    for i in range(0,len(MA10)-1):
        for k in range(i,len(MA10)-1):
                if((MA10[i+1] - MA10[i]) > 0 and (MA10[k+1] - MA10[k]) < 0):    
                    PreSignal = 'SELL'
                    Presignal_List.append(PreSignal)
                    break
                elif((MA10[i+1] - MA10[i]) < 0 and (MA10[k+1] - MA10[k]) > 0):
                    PreSignal = 'BUY'
                    Presignal_List.append(PreSignal)
                    break
                elif(k==(len(MA10)-3)):
                    PreSignal = 'NO SIGNAL'
                    Presignal_List.append(PreSignal)
                    
    return Presignal_List

def Triple_MA():                             #riceve 3 interi e restituisce tre medie mobili
    NumOfMA=input("Number of MA: ")          #una per ogni periodo, il periodo è definito dagli interi
    NumOfMA = int(NumOfMA)
    MArangeList = []
    MA_list = []

    for i in range(0, NumOfMA):    
        MArange = input("Insert the time period: ")
        MArange = int(MArange)
        MArangeList.append(MArange)
        MA = MobileAverage(MArangeList[i] , Date)
        MA_list.append(MA)
        
    return MA_list


def Triple_Crossover_Signal():               #l'intersezioni della media mobile breve con quella media da un segnale buy o sell
    NumOfMA=3                                #in base al fatto che la media breve arrivi da su o da giù
    MArangeValues=[4,9,18]                   #La media mobile breve tocca la lunga e da un altro segnale
    MArangeList = []                         #la media mobile media tocca la lunga e crea un segnale buy o sell
    MA_list = []                             #3 segnali sell danno un sell
    Signal_matrix = []                       #3 segnali buy danno un buy
    Signal_list = []                         #negli altri casi, nessun segnale
    n_buys = 0
    n_sells = 0
    Final_signal_list = []
    
    for i in range(0, NumOfMA):    
        MArange = MArangeValues[i]
        MArangeList.append(MArange)
        MA = MobileAverage(MArangeList[i] , Date)
        MA_list.append(MA)
    
    for i in range(1,len(MA_list[0])):
        for j in range(0,NumOfMA-1):
            if((MA_list[j][i-1] > MA_list[j+1][i-1]) and (MA_list[j][i] == MA_list[j+1][i])):
                Presignal = 'SELL'
            elif(j==0 and (MA_list[j][i-1] > MA_list[j+2][i-1]) and (MA_list[j][i] == MA_list[j+2][i])):
                Presignal = 'SELL'
            elif(j==0 and (MA_list[j][i-1] < MA_list[j+2][i-1]) and (MA_list[j][i] == MA_list[j+2][i])):
                Presignal = 'BUY'
            elif((MA_list[j][i-1] < MA_list[j+1][i-1]) and (MA_list[j][i] == MA_list[j+1][i])):
                Presignal = 'BUY'
            else:
                Presignal = 'NO SIGNAL'
            Signal_list.append(Presignal)
        Signal_matrix.append(Signal_list)
        Signal_list = []
    
    for v in Signal_matrix:
        for n in Signal_list:
            if(Signal_list[n] == 'BUY'):
                ++n_buys
            elif(Signal_list[n] == 'SELL'):
                ++n_sells
            else:
                continue
        if(n_buys == 3 ):
            Final_signal = 'BUY'
        elif(n_sells == 3):
            Final_signal = 'SELL'
        else:
            Final_signal = 'NO SIGNAL'
        Final_signal_list.append(Final_signal)
        
    return Final_signal_list


def Simple_Crossover_Signal():                           #Questo segnale è migliore del triple crossover signal
    NumOfMA=2                                            #e' una intersezione semplice tra due medie mobili e funziona meglio del  
    MArangeValues=[10,50]                                #triplo crossover, anche se questo funziona meglio con i future su commodities
    MArangeList = []
    MA_list = []
    Signal_list = []
    n_buys = 0
    n_sells = 0

    for i in range(0, NumOfMA):    
        MArange = MArangeValues[i]
        MArangeList.append(MArange)
        MA = MobileAverage(MArangeList[i] , Date)
        MA_list.append(MA)
    
    for i in range(1,len(MA_list[0])):
            j=0
            if((MA_list[j][i-1] > MA_list[j+1][i-1]) and (MA_list[j][i] == MA_list[j+1][i])):
                Presignal = 'SELL'
            elif((MA_list[j][i-1] < MA_list[j+1][i-1]) and (MA_list[j][i] == MA_list[j+1][i])):
                Presignal = 'BUY'
            else:
                Presignal = 'NO SIGNAL'
            Signal_list.append(Presignal)
        
    return Signal_list

# %%
def MAplot():
    from plotly.subplots import make_subplots
    import plotly.graph_objects as go
    fig = make_subplots(rows=1, cols=1)
    NumOfMA=input("Number of MA: ")
    NumOfMA = int(NumOfMA)
    MArangeList = []
    
    for i in range(0, NumOfMA) :
        MArange = input("Insert the time period: ")
        MArange = int(MArange)
        MArangeList.append(MArange)
        MA = MobileAverage(MArangeList[i] , Date)
        title = "Mobile Av. " + str(MArangeList[i]) + " days"
        fig.add_trace(go.Scatter(name= title, x=Date, y=MA), row=1, col=1)
        
    fig.add_trace(go.Scatter(name="Stock Price", x=Date, y=closing_price), row=1, col=1)
    
    return fig

# %%
MAplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1884/3161798037.py in <module>
# ----> 1 MAplot()
#
# ~\AppData\Local\Temp/ipykernel_1884/2797910144.py in MAplot()
#       3     import plotly.graph_objects as go
#       4     fig = make_subplots(rows=1, cols=1)
# ----> 5     NumOfMA=input("Number of MA: ")
#       6     NumOfMA = int(NumOfMA)
#       7     MArangeList = []
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # BOLLINGER BANDS

# %%
def Bollinger():                              #crea le bande di bollinger
    import math
    BigDS = []
    MiniDS = []
    SqrdErr=0
    BollingerMA=MobileAverage(20,Date)
    for i in range(0,len(closing_price)):
        SqrdErr = SqrdErr + ((closing_price[i] - closing_price.mean())**2)     #errore quadrato
        if(i==0):
            continue
        else:
            DS = math.sqrt((SqrdErr)/len(closing_price[0:i]))                   #deviazione standard
        BigDS.append(BollingerMA[i] + (0.6*DS) )
        MiniDS.append(BollingerMA[i] - (0.6*DS) )     #fattore di attualizzazione 0.6 che moltiplica la deviazione standard
    DS_Matrix = [BigDS,BollingerMA,MiniDS]            #di solito il fattore è = a 3, ma con 0.6 sembra funzionare meglio
    
    return DS_Matrix

# %%
def Bollinger_Signal():                                       #quando il prezzo tocca la banda alta si vende
    Signal_list = []                                          #quando tocca la banda bassa si compra
    Bollinger_output = Bollinger()
    for i in range(0, len(closing_price)):
        if(closing_price[i] > Bollinger_output[1][i]):
            Final_signal = 'SELL'
        elif(closing_price[i] < Bollinger_output[1][i]):
            Final_signal = 'BUY'
        elif(closing_price[i] == Bollinger_output[1][i]):
            Final_signal = 'NO SIGNAL'
        Signal_list.append(Final_signal)
    
    return Signal_list

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go


def Bollinger_plot():
    
    fig = make_subplots(rows=1, cols=1)
    
    DS_Matrix = Bollinger()
    
    fig.add_trace(go.Scatter(name="Stock Price", x=Date, y=closing_price), row=1, col=1)
    fig.add_trace(go.Scatter(name="Big Bollinger Band", x=Date, y=DS_Matrix[0]), row=1, col=1)
    fig.add_trace(go.Scatter(name="Bollinger 20 days mobile average", x=Date, y=DS_Matrix[1]), row=1, col=1)
    fig.add_trace(go.Scatter(name="Little Bollinger Band", x=Date, y=DS_Matrix[2]), row=1, col=1)
    
    return fig

Bollinger_plot()

# %% [markdown]
# # RSI

# %%
Date
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 2851   2021-10-25
# 2852   2021-10-26
# 2853   2021-10-27
# 2854   2021-10-28
# 2855   2021-10-29
# Name: Date, Length: 2856, dtype: datetime64[ns]

# %%
def RSI(Date, flag=True):                               #cerca su wikipedia la formula del Relative Strenght Index
    import pandas as pd                                 
    
    if(flag):
        timeframe_int = 14
        timeframe = float(timeframe_int)
    else:
        timeframe_int = input("Choose the time period for the RSI (We advice to use 14 days): ")
        timeframe = float(timeframe_int)
    
    Bigdiff_list = []
    Lildiff_list = []
    RSI_list = []
    
    for i in range(0,len(closing_price)):
        if (i==0):
            closing_price_diff_major = 0
            closing_price_diff_major = 0
        else:
            if (closing_price[i] > closing_price[i-1]):
                closing_price_diff_major = closing_price[i] - closing_price[i-1]
                Bigdiff_list.append(closing_price_diff_major)
                Lildiff_list.append(0)
            elif (closing_price[i] < closing_price[i-1]):
                closing_price_diff_minor = closing_price[i-1] - closing_price[i] 
                Lildiff_list.append(closing_price_diff_minor)
                Bigdiff_list.append(0)
            elif (closing_price[i] == closing_price[i-1]):
                Lildiff_list.append(0)
                Bigdiff_list.append(0)
            
            if (i-timeframe < 0):
                Major_Average = sum(Bigdiff_list[0:i])/(timeframe)
                Minor_Average = sum(Lildiff_list[0:i])/(timeframe)
            else:
                Major_Average = sum(Bigdiff_list[(i-timeframe_int):i])/(timeframe)
                Minor_Average = sum(Lildiff_list[(i-timeframe_int):i])/(timeframe)
                
            if (Minor_Average == 0 and Major_Average > 0):
                RSI = 100
                RSI_list.append(RSI)
            elif (Minor_Average == 0 and Major_Average == 0):
                pass
            else:
                RS = Major_Average/Minor_Average
                RSI = 100 - (100/(1+RS))
                RSI_list.append(RSI)
                
    RSI_df=pd.DataFrame(RSI_list)
    RSI_df.rename(columns={0:'RSI'}, inplace= True)
    RSI_date_df = pd.concat([Date, RSI_df], axis=1, join="inner")
    
    return RSI_date_df

# %%
def RSI_Signal():
    Signal_List = []
    RSI_df = RSI(Date, flag=True)
    RSI_value = RSI_df['RSI']
    for i in range(0,len(RSI_value)):
        if((RSI_value[i] > 50) and (RSI_value[i] <= 100)):
            Final_Signal = 'SELL'
        elif(RSI_value[i] == 50):
            Final_Signal = 'NO SIGNAL'
        elif((RSI_value[i] < 50) and (RSI_value[i] >= 0)):
            Final_Signal = 'BUY'
        Signal_List.append(Final_Signal)
    
    return Signal_List

# %%
RSI_df=RSI(Date)
RSI_df
# Out:
#            Date        RSI
# 0    2010-06-29   0.000000
# 1    2010-06-30   0.000000
# 2    2010-07-01   0.000000
# 3    2010-07-02   0.000000
# 4    2010-07-06   0.000000
# ...         ...        ...
# 2850 2021-10-22  94.871242
# 2851 2021-10-25  92.624625
# 2852 2021-10-26  92.846381
# 2853 2021-10-27  96.118207
# 2854 2021-10-28  96.459907
#
# [2855 rows x 2 columns]

# %%
def RSI_Bar_plot():
    RSI_df = RSI(Date)
    
    layout = go.Layout(title='RSI and Stock price',
                   yaxis=dict(title='Stock Price'),
                   yaxis2=dict(title='RSI',
                               overlaying='y',
                               side='right'))
    
    trace1 = go.Scatter(x=RSI_df["Date"], y=closing_price, name="Stock Price", yaxis='y1')
    trace2 = go.Bar(x=RSI_df["Date"], y=RSI_df["RSI"], name="RSI", marker_color='red', yaxis='y2')
    
    data = [trace1, trace2]
    
    return go.Figure(data= data, layout=layout)

# %%
def RSI_Line_plot():
    RSI_df = RSI(Date)
    
    layout = go.Layout(title='RSI and Stock price',
                       yaxis=dict(title='Stock Price'),
                       yaxis2=dict(title='RSI',
                                   overlaying='y',
                                   side='right'))
    
    trace1 = go.Scatter(x=RSI_df["Date"], y=closing_price, name="Stock Price", yaxis='y1')
    trace2 = go.Scatter(x=RSI_df["Date"], y=RSI_df["RSI"], name="RSI", yaxis='y2')
    
    data= [trace1, trace2]
    
    return go.Figure(data=data, layout=layout)

# %%
RSI_Bar_plot()

# %%
RSI_Line_plot()

# %% [markdown]
# # CHANGE MOMENTUM OSCILLATOR

# %%
def CMO(Date):                                                  #una semplice differenza del prezzo con il prezzo[i] 
    time_frame= input("Insert the time period: ")               #con il prezzo[i-periodo di tempo fisso scelto]
    time_frame = int(time_frame)                                #esempio: prezzo[giorno 30] - prezzo[giorno 10] = CMO[30]
    M_list = []
    
    for i in range(0, len(closing_price)):
        if(i-time_frame<0):
            M = closing_price[i] - closing_price[0]
            M_list.append(M)
        elif(i-time_frame>=0):
            M = closing_price[i] - closing_price[i-time_frame]
            M_list.append(M)
    
    M_df=pd.DataFrame(M_list)
    M_df.rename(columns={0:'CMO'}, inplace= True)
    M_date_df = pd.concat([Date, M_df], axis=1, join="inner")
    
    return M_date_df

# %%
def CMO_Signal():
    time_frame= 20
    M_list = []
    
    for i in range(0, len(closing_price)):
        if(i-time_frame<0):
            M = closing_price[i] - closing_price[0]
            M_list.append(M)
        elif(i-time_frame>=0):
            M = closing_price[i] - closing_price[i-time_frame]
            M_list.append(M)
    
    M_df=pd.DataFrame(M_list)
    M_df.rename(columns={0:'CMO'}, inplace= True)
    M_date_df = pd.concat([Date, M_df], axis=1, join="inner")
    
    CMO_value = M_date_df['CMO']
    Signal_List = []
    
    for i in range(0,len(closing_price)):
        if(CMO_value[i] > 0):
            Final_Signal = 'SELL'
        elif(CMO_value[i] == 0):
            Final_Signal = 'NO SIGNAL'
        elif(CMO_value[i] < 0):
            Final_Signal = 'BUY'
        Signal_List.append(Final_Signal)
    
    return Signal_List

# %%
def CMO_plot():
    M_date_df=CMO(Date)
    
    layout = go.Layout(title='CMO and Stock price',
                       yaxis=dict(title='Stock Price'),
                       yaxis2=dict(title='CMO',
                                   overlaying='y',
                                   side='right'))
    
    trace1= go.Scatter(name="Stock Price", x=Date, y=closing_price, yaxis='y1')
    trace2= go.Scatter(name="Change Momentum Oscillator", x=M_date_df['Date'], y=M_date_df['CMO'], yaxis='y2')
    
    data= [trace1, trace2]
    
    return go.Figure(data=data, layout=layout)

CMO_plot()

# %% [markdown]
# # ELLIOT WAVES

# %%
#Creare un riconoscitore delle fasi "5-3" della teoria di elliot, fare prima l'indicatore di Fibonacci

# %% [markdown]
# # FIBONACCI INDICATOR

# %%
#Creare l'indicatore di fibonacci

# %% [markdown]
# # TRADING SIGNAL Algorithm

# %%
def Market_Discover_and_Trading_Signal():
    main_list = []
    ticker_list = ['FB','MC']
    DEFINITIVE_list = []
    DEFINITIVE_MATRIX = []

    nbuy= 0
    nsell = 0
    nosignal = 0
    
    for stock_name in ticker_list: 
        msft = yf.Ticker(stock_name)
        info=[["Info", msft.info],["historical market data", msft.history(period="max")],["Actions", msft.actions],["Dividends", msft.dividends],["Splits", msft.splits],["Financials", msft.financials],
              ["Quarterly financials", msft.quarterly_financials],["Major holders", msft.major_holders],["Institutional holders", msft.institutional_holders],["Balance sheet", msft.balance_sheet],
              ["Quarterly Balance sheet", msft.quarterly_balance_sheet], ["Cash Flow", msft.cashflow], ["Quarterly cash flow", msft.quarterly_cashflow], ["Earnings", msft.earnings],
              ["Quarterly earnings", msft.quarterly_earnings], ["Sustainability", msft.sustainability],  ["Recommendations", msft.recommendations], ["Calendar of next events", msft.calendar],
              ["Options expirations", msft.options]]
        
        stock_price=pd.DataFrame(info[1][1])
        stock_price.reset_index(inplace=True)

        closing_price = stock_price["Close"]
        Date = stock_price["Date"]

        indicator0 = MA_signal_Fermat()
        indicator1 = Simple_Crossover_Signal()
        indicator2 = Bollinger_Signal()
        indicator3 = RSI_Signal()
        indicator4 = CMO_Signal()
    
        sub_list = [indicator0, indicator1, indicator2, indicator3, indicator4]
        main_list.append(sub_list)
    
        for j in range(0,len(ticker_list)):
            for n in range(0,len(closing_price)):
                for i in range(0,5):
                    if(main_list[j][i][n] == 'BUY'):
                        ++nbuy
                    elif(main_list[j][i][n] == 'SELL'):
                        ++nsell
                    else:
                        ++nosignal
                    if(nbuy==4):
                        DEFINITIVE = 'BUY'
                        OPERATION_AT_PRICE = closing_price[n]
                    elif(nsell==4):
                        DEFINITIVE = 'SELL'
                        OPERATION_AT_PRICE = closing_price[n]
                    else:
                        DEFINITIVE = 'WAIT'
                        OPERATION_AT_PRICE = closing_price[n]
                DEFINITIVE_list.append([DEFINITIVE,OPERATION_AT_PRICE])
            DEFINITIVE_MATRIX.append([ticker_list[j],DEFINITIVE_list])
        
    return DEFINITIVE_MATRIX

# %%
indicator0 = MA_signal_Fermat()
indicator1 = Simple_Crossover_Signal()
indicator2 = Bollinger_Signal()
indicator3 = RSI_Signal()
indicator4 = CMO_Signal()

input="1"

if(input=="1"):
    print("FERMAT","\n\n",indicator0,"\n\n","MA CROSS","\n\n",indicator1,"\n\n","Bollinger","\n\n",indicator2,"\n\n","RSI","\n\n",indicator3,"\n\n","CMO","\n\n",indicator4)
elif(input=="0"):
    print(len(indicator0),len(indicator1),len(indicator2),len(indicator3),len(indicator4))
# Out:
# FERMAT
#
#  ['BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'NO SIGNAL', 'BUY', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'NO SIGNAL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL' ...
#
#  MA CROSS
#
#  ['NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIGNAL', 'NO SIG ...
#
#  Bollinger
#
#  ['SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'SEL ...
#
#  RSI
#
#  ['BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'NO SIGNAL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BU ...
#
#  CMO
#
#  ['NO SIGNAL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'NO SIGNAL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'SELL', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', 'BUY', ...
